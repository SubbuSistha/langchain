# %% [markdown]
# # Tools

# %%
from langchain_community.tools import DuckDuckGoSearchRun

ddsg_tool = DuckDuckGoSearchRun()
print(ddsg_tool.run("What is the capital of France?"))
# Out:
# d:\LangChain\langchain\.venv\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:47: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# d:\LangChain\langchain\.venv\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:48: UserWarning: backend='api' is deprecated, using backend='auto'
#   ddgs_gen = ddgs.text(
# No good DuckDuckGo Search Result was found
